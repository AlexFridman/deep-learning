# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:48, 648KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here

def mikolov_subsampling(int_words, t):
    from collections import Counter
    
    total_count = len(int_words)
    freqs = {w: count / total_count 
             for w, count in Counter(int_words).items()}
    discard_probs = {w: 1 - np.sqrt(t / freq) 
                     for w, freq in freqs.items()}
    
    return [w for w in int_words 
            if discard_probs[w] < np.random.random()]

train_words = mikolov_subsampling(int_words, 1e-5)

# %%
len(int_words), len(train_words)
# Out:
# (16680599, 4629053)

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(1, window_size + 1)
    start = idx - R if idx - R > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx + 1:stop + 1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(
        dtype=tf.int32,
        shape=[None],
        name='inputs'
    )
    labels = tf.placeholder(
        dtype=tf.int32,
        shape=[None, None],
        name='labels'
    )

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200

with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], stddev=0.1))
    softmax_b = tf.Variable(tf.zeros([n_vocab]))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        weights=softmax_w,
        biases=softmax_b, 
        labels=labels,
        inputs=embed,
        num_sampled=n_sampled,
        num_classes=n_vocab
    )
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random


with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6690 0.0196 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6148 0.0170 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5099 0.0174 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6090 0.0180 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5053 0.0181 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5291 0.0174 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5328 0.0173 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5757 0.0172 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4835 0.0173 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4636 0.0173 sec/batch
# Nearest to and: canonical, tomb, exists, theophoric, mitrailleuse, betrothed, bestow, squadron,
# Nearest to he: tequila, karine, populous, koreans, helpless, racer, sued, confront,
# Nearest to seven: prasad, popes, esa, schemes, preservation, egyptologist, wet, two,
# Nearest to been: collider, tool, freire, dusty, banach, glyphs, cochran, unattainable,
# Nearest to for: ethnographers, psi, sonic, herold, weave, fenced, infinity, merozoites,
# Nearest to if: flashed, nabla, industrialized, talisman, ovule, leakage, escher, cocker,
# Nearest to over: peripheral, counties, accede, indicia, allergen, monocotyledons, horn, kaze,
# Nearest to has: bulletins, pavlova, alkaline, rebooted, atal, themselves, grimoald, engaged,
# Nearest to applications: cd, lobe, dueling, recreating, banshee, daf, akiva, mercedes,
# Nearest to something: belles, ctesiphon, mycobacterium, airstream, pursuant, standout, mlb, windshield,
# Nearest to existence: studia, harkonnen, cornish, epidemiological, iala, hear, eloheinu, nzenberg,
# Nearest to scale: manhunt, accession, id, overviews, comneni, yerkes, wissenschaften, seaboard,
# Nearest to event: sandwiches, gianfranco, stress, chechen, vf, bf, adjusts, conflict,
# Nearest to freedom: forman, painstaking, inquisitors, gripping, alcmene, mendeleev, sher, viru,
# Nearest to creation: nicholson, spreads, disregards, incubation, instruction, celia, hbp, luciano,
# Nearest to shown: kath, orthographic, korzybski, rivets, skilling, achieve, flourish, gzip,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4814 0.0183 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4072 0.0178 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3302 0.0180 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2498 0.0177 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1796 0.0177 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1875 0.0167 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1333 0.0171 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0629 0.0179 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9978 0.0172 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0103 0.0171 sec/batch
# Nearest to and: exists, solving, canonical, minimal, evolve, tomb, squadron, populated,
# Nearest to he: tequila, declared, this, racer, populous, koreans, whichever, confront,
# Nearest to seven: two, popes, preservation, schemes, prasad, esa, experts, wet,
# Nearest to been: collider, tool, throughout, hands, broadway, an, thirds, talents,
# Nearest to for: sonic, ethnographers, infinity, psi, context, weave, form, libraries,
# Nearest to if: it, toward, an, industrialized, give, liberals, flashed, above,
# Nearest to over: peripheral, counties, introduction, accede, indicia, horn, city, monocotyledons,
# Nearest to has: themselves, bulletins, engaged, year, spelling, rebooted, ownership, interior,
# Nearest to applications: cd, lobe, it, mercedes, recreating, francis, dueling, original,
# Nearest to something: cambridge, holiday, mlb, strain, dualism, belles, standout, pursuant,
# Nearest to existence: hear, successive, cornish, escape, petition, branches, studia, capstone,
# Nearest to scale: accession, manhunt, id, seaboard, overviews, support, calm, excellence,
# Nearest to event: sandwiches, stress, gianfranco, conflict, dialogue, cpt, repeated, chechen,
# Nearest to freedom: gripping, inquisitors, forman, diseased, jule, colour, produced, kim,
# Nearest to creation: instruction, spreads, distributed, stores, live, part, nicholson, meet,
# Nearest to shown: flourish, achieve, engaged, orthographic, read, utilized, about, bona,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9500 0.0178 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9355 0.0170 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9005 0.0170 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8536 0.0168 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8124 0.0167 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8159 0.0168 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8149 0.0171 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7968 0.0170 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8060 0.0174 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7642 0.0169 sec/batch
# Nearest to and: canonical, exists, solving, evolve, minimal, reunification, squadron, dorset,
# Nearest to he: tequila, declared, populous, this, racer, confront, whichever, qualified,
# Nearest to seven: two, popes, prasad, preservation, esa, egyptologist, jorge, morals,
# Nearest to been: collider, tool, throughout, fay, broadway, undetected, resultant, thirds,
# Nearest to for: ethnographers, sonic, weave, infinity, psi, leak, ea, attorney,
# Nearest to if: nabla, industrialized, vaporized, leakage, evil, barbarian, it, flashed,
# Nearest to over: peripheral, counties, introduction, accede, criticisms, horn, indicia, monocotyledons,
# Nearest to has: themselves, alkaline, bulletins, spelling, varies, ownership, engaged, betray,
# Nearest to applications: cd, dueling, it, lobe, recreating, troma, mercedes, francis,
# Nearest to something: standout, cambridge, holiday, strain, dualism, belles, propagated, mlb,
# Nearest to existence: hear, studia, petition, successive, stuck, surroundings, xl, branches,
# Nearest to scale: accession, manhunt, id, excellence, overviews, seaboard, leaf, yerkes,
# Nearest to event: sandwiches, stress, principal, conflict, gianfranco, dialogue, adjusts, repeated,
# Nearest to freedom: gripping, produced, colour, diseased, greg, gascon, phd, inquisitors,
# Nearest to creation: spreads, instruction, stores, growing, distributed, live, nicholson, port,
# Nearest to shown: orthographic, achieve, flourish, read, utilized, engaged, about, gzip,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7832 0.0179 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7647 0.0177 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7186 0.0176 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7164 0.0170 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7389 0.0173 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7201 0.0175 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7232 0.0170 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7282 0.0168 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.6980 0.0170 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6610 0.0172 sec/batch
# Nearest to and: canonical, exists, solving, dorset, bestow, funnel, minimal, betrothed,
# Nearest to he: tequila, declared, populous, confront, racer, qualified, underpants, assault,
# Nearest to seven: two, six, prasad, four, egyptologist, esa, popes, pryor,
# Nearest to been: collider, throughout, tool, undetected, resultant, fay, taught, mistresses,
# Nearest to for: sonic, ethnographers, weave, psi, leak, ea, devries, infinity,
# Nearest to if: nabla, leakage, vaporized, barbarian, maybe, it, above, cocker,
# Nearest to over: counties, accede, introduction, peripheral, indicia, allergen, criticisms, horn,
# Nearest to has: bulletins, alkaline, betray, themselves, ownership, coma, vapour, rebooted,
# Nearest to applications: cd, dueling, recreating, it, troma, original, dagger, lobe,
# Nearest to something: standout, dualism, strain, belles, mlb, propagated, cambridge, ctesiphon,
# Nearest to existence: studia, hear, nzenberg, downs, petition, iala, escape, epidemiological,
# Nearest to scale: accession, yerkes, manhunt, rooted, thermionic, wissenschaften, seaboard, porter,
# Nearest to event: sandwiches, stress, principal, gianfranco, courtyard, chechen, meteorologists, conflict,
# Nearest to freedom: gripping, forman, inquisitors, painstaking, appeal, kim, greg, gunpoint,
# Nearest to creation: spreads, nicholson, stores, instruction, luciano, live, port, starboard,
# Nearest to shown: orthographic, achieve, flourish, about, read, utilized, kath, engaged,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6809 0.0177 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6797 0.0173 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6137 0.0173 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6324 0.0169 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6426 0.0169 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6297 0.0173 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6313 0.0122 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5477 0.0172 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5136 0.0175 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5087 0.0176 sec/batch
# Nearest to and: dorset, canonical, steeply, parenthesis, bestow, funnel, conquer, solving,
# Nearest to he: tequila, declared, underpants, married, assault, confront, entranced, whichever,
# Nearest to seven: two, six, four, jorge, egyptologist, prasad, popes, driver,
# Nearest to been: collider, throughout, resultant, glyphs, tool, undetected, expressways, taught,
# Nearest to for: sonic, weave, ethnographers, labs, devries, psi, ea, measured,
# Nearest to if: nabla, leakage, vaporized, an, cocker, algorithm, above, opiates,
# Nearest to over: counties, accede, indicia, peripheral, kaze, allergen, city, attending,
# Nearest to has: coma, alkaline, bulletins, vapour, varies, ownership, travelers, betray,
# Nearest to applications: it, cd, troma, dueling, original, recreating, dagger, wheat,
# Nearest to something: standout, dualism, belles, ctesiphon, strain, brain, silence, considers,
# Nearest to existence: nzenberg, studia, hear, epidemiological, alludes, petition, downs, bahadur,
# Nearest to scale: accession, yerkes, manhunt, rooted, fraktion, thermionic, predominated, catalogued,
# Nearest to event: sandwiches, stress, gianfranco, principal, meteorologists, courtyard, chechen, latex,
# Nearest to freedom: gripping, inquisitors, appeal, painstaking, forman, gunpoint, sher, gascon,
# Nearest to creation: spreads, nicholson, luciano, stores, instruction, incubation, starboard, live,
# Nearest to shown: orthographic, achieve, about, read, kath, flourish, utilized, rivets,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4990 0.0175 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4982 0.0175 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4653 0.0179 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5527 0.0173 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5180 0.0171 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4833 0.0174 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4744 0.0175 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3934 0.0177 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4317 0.0178 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4175 0.0183 sec/batch
# Nearest to and: canonical, steeply, solving, funnel, dorset, parenthesis, squeezing, evolve,
# Nearest to he: tequila, declared, his, underpants, had, helpless, confront, entranced,
# Nearest to seven: two, four, six, prasad, popes, egyptologist, jorge, esa,
# Nearest to been: collider, throughout, resultant, taught, archeological, glyphs, tool, undetected,
# Nearest to for: sonic, labs, weave, ethnographers, devries, measured, ea, powerlessness,
# Nearest to if: nabla, integers, algorithm, cocker, opiates, an, exactly, leakage,
# Nearest to over: indicia, counties, peripheral, accede, city, kaze, attending, malarial,
# Nearest to has: alkaline, coma, vapour, tram, ownership, incentive, bulletins, robberies,
# Nearest to applications: cd, it, original, troma, dueling, recreating, lobe, liquidate,
# Nearest to something: standout, brain, dualism, belles, silence, looking, ctesiphon, propagated,
# Nearest to existence: epidemiological, alludes, hear, nzenberg, studia, escape, xl, openings,
# Nearest to scale: yerkes, accession, rooted, fraktion, thermionic, manhunt, petrarch, preprocessing,
# Nearest to event: sandwiches, stress, gianfranco, meteorologists, chechen, principal, eichmann, courtyard,
# Nearest to freedom: forman, appeal, inquisitors, painstaking, gripping, gascon, gunpoint, sher,
# Nearest to creation: spreads, luciano, stores, nicholson, incubation, neither, instruction, detachments,
# Nearest to shown: orthographic, about, achieve, read, utilized, kath, rivets, rigorous,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4156 0.0177 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4145 0.0175 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4372 0.0176 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3880 0.0173 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3906 0.0174 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4525 0.0171 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3780 0.0171 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3702 0.0172 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4121 0.0173 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3777 0.0175 sec/batch
# Nearest to and: canonical, steeply, parenthesis, funnel, solving, hippies, mitrailleuse, squeezing,
# Nearest to he: tequila, his, declared, had, helpless, underpants, confront, entranced,
# Nearest to seven: two, four, six, prasad, popes, five, egyptologist, jorge,
# Nearest to been: collider, throughout, archeological, taught, resultant, glyphs, tool, undetected,
# Nearest to for: sonic, ethnographers, weave, lexicographers, powerlessness, numeric, localization, labs,
# Nearest to if: nabla, opiates, algorithm, vaporized, integers, an, leakage, dirkjan,
# Nearest to over: accede, counties, peripheral, humphries, loan, monocotyledons, kaze, malarial,
# Nearest to has: alkaline, finland, coma, tram, ownership, robberies, vapour, bulletins,
# Nearest to applications: cd, original, troma, it, dueling, recreating, suffers, liquidate,
# Nearest to something: standout, dualism, looking, considers, silence, not, windshield, belles,
# Nearest to existence: alludes, hear, epidemiological, xl, blaxploitation, petition, but, studia,
# Nearest to scale: rooted, thermionic, fraktion, yerkes, accession, manhunt, luminosity, subatomic,
# Nearest to event: sandwiches, stress, meteorologists, chastity, mice, latex, gianfranco, principal,
# Nearest to freedom: appeal, painstaking, gripping, forman, inquisitors, vested, sher, gascon,
# Nearest to creation: spreads, stores, detachments, nicholson, incubation, neither, luciano, disregards,
# Nearest to shown: orthographic, about, achieve, read, utilized, flourish, rivets, rigorous,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3951 0.0181 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4222 0.0176 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3570 0.0172 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3835 0.0176 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3959 0.0175 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3669 0.0172 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3842 0.0177 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3688 0.0178 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3209 0.0180 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3466 0.0184 sec/batch
# Nearest to and: steeply, the, canonical, funnel, solving, evolve, rewarding, hippies,
# Nearest to he: tequila, his, declared, had, confront, entranced, assault, underpants,
# Nearest to seven: two, four, six, five, popes, prasad, egyptologist, jorge,
# Nearest to been: collider, taught, throughout, archeological, resultant, cochran, ruining, scribe,
# Nearest to for: sonic, numeric, powerlessness, lexicographers, herold, ethnographers, ea, localization,
# Nearest to if: nabla, opiates, algorithm, integers, dirkjan, vaporized, an, forgo,
# Nearest to over: accede, counties, loan, sagara, underway, criticisms, humphries, monocotyledons,
# Nearest to has: alkaline, finland, coma, kettle, tram, varies, ownership, bulletins,
# Nearest to applications: cd, original, troma, dueling, recreating, developers, emulator, suffers,
# Nearest to something: looking, standout, dualism, silence, windshield, considers, belles, seems,
# Nearest to existence: hear, epidemiological, alludes, blaxploitation, petition, but, scholarly, eloheinu,
# Nearest to scale: thermionic, fraktion, yerkes, rooted, luminosity, fai, manhunt, seaboard,
# Nearest to event: sandwiches, chastity, principal, stress, meteorologists, katz, mice, latex,
# Nearest to freedom: appeal, painstaking, tendencies, vested, sher, gripping, forman, danner,
# Nearest to creation: detachments, spreads, taifa, luciano, disregards, neither, hainaut, nicholson,
# Nearest to shown: orthographic, about, achieve, read, flourish, kath, utilized, rigorous,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3544 0.0179 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3054 0.0178 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4028 0.0178 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3767 0.0176 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3687 0.0176 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2854 0.0177 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2942 0.0170 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3562 0.0167 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2208 0.0168 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2930 0.0172 sec/batch
# Nearest to and: steeply, caleb, funnel, the, constituci, solving, rewarding, consultative,
# Nearest to he: his, tequila, assault, confront, had, entranced, underpants, rquez,
# Nearest to seven: two, four, six, five, nine, prasad, egyptologist, one,
# Nearest to been: collider, throughout, archeological, taught, resultant, ruining, glyphs, dignity,
# Nearest to for: sonic, ea, rehabilitate, herold, numeric, localization, weave, memorizing,
# Nearest to if: nabla, opiates, integers, algorithm, dirkjan, exactly, forgo, unambiguous,
# Nearest to over: accede, counties, malarial, sagara, underway, humphries, loan, quadrupole,
# Nearest to has: finland, alkaline, varies, coma, cheapest, tram, kettle, malawian,
# Nearest to applications: cd, troma, original, dueling, emulator, developers, recreating, microsoft,
# Nearest to something: looking, silence, dualism, standout, considers, windshield, ironside, subterfuge,
# Nearest to existence: epidemiological, alludes, petition, blaxploitation, studia, divorces, hear, bahadur,
# Nearest to scale: fraktion, thermionic, yerkes, rooted, luminosity, fai, manhunt, seaboard,
# Nearest to event: sandwiches, meteorologists, principal, katz, chastity, stress, chechen, mice,
# Nearest to freedom: appeal, inquisitors, tendencies, strove, vested, danner, sher, youngstown,
# Nearest to creation: detachments, luciano, taifa, disregards, spreads, thinking, pivot, bunter,
# Nearest to shown: orthographic, achieve, read, about, kath, flourish, rigorous, rivets,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3173 0.0175 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2907 0.0170 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3221 0.0075 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2456 0.0171 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2490 0.0168 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2016 0.0172 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2154 0.0172 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2356 0.0168 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2211 0.0171 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1878 0.0178 sec/batch
# Nearest to and: the, steeply, huntingford, constituci, rewarding, caleb, solving, rambo,
# Nearest to he: his, tequila, confront, had, declared, underpants, entranced, went,
# Nearest to seven: two, four, five, six, mallarm, popes, prasad, egyptologist,
# Nearest to been: collider, throughout, archeological, taught, glyphs, resultant, ruining, dumping,
# Nearest to for: sonic, rehabilitate, ea, herold, lexicographers, belied, powerlessness, woodlawn,
# Nearest to if: nabla, opiates, integers, algorithm, dirkjan, exactly, forgo, an,
# Nearest to over: accede, sagara, malarial, humphries, attending, underway, indicia, tall,
# Nearest to has: alkaline, cheapest, finland, tram, malawian, varies, fabrication, kettle,
# Nearest to applications: cd, original, troma, dueling, developers, emulator, recreating, microsoft,
# Nearest to something: silence, looking, dualism, standout, belles, mlb, ironside, considers,
# Nearest to existence: petition, alludes, blaxploitation, epidemiological, bahadur, divorces, mut, scholarly,
# Nearest to scale: fraktion, thermionic, luminosity, fai, yerkes, rooted, subatomic, preprocessing,
# Nearest to event: sandwiches, meteorologists, principal, katz, chastity, chechen, mice, gianfranco,
# Nearest to freedom: appeal, danner, colonna, inquisitors, religious, tendencies, forman, gripping,
# Nearest to creation: detachments, disregards, luciano, spreads, taifa, thinking, azeris, pivot,
# Nearest to shown: orthographic, about, achieve, read, flourish, kath, bona, uribe,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2589 0.0176 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2545 0.0169 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2316 0.0168 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1338 0.0172 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1854 0.0178 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1759 0.0169 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1850 0.0175 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1825 0.0178 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.2014 0.0177 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1906 0.0169 sec/batch
# Nearest to and: solving, the, steeply, aquifer, uppermost, evolve, pipelines, rambo,
# Nearest to he: his, tequila, confront, had, underpants, went, helpless, odysseus,
# Nearest to seven: two, four, five, six, mallarm, prasad, nine, three,
# Nearest to been: collider, throughout, taught, resultant, archeological, glyphs, ruining, rabies,
# Nearest to for: numeric, localization, powerlessness, algorithm, rehabilitate, memorizing, ea, sonic,
# Nearest to if: nabla, opiates, integers, an, algorithm, exactly, deteriorates, dirkjan,
# Nearest to over: sagara, attending, malarial, tall, quadrupole, accede, dheas, kaze,
# Nearest to has: alkaline, kettle, cheapest, finland, unbelievable, coma, fabrication, mindedness,
# Nearest to applications: cd, original, recreating, troma, dueling, it, developers, emulator,
# Nearest to something: silence, looking, dualism, standout, mlb, belles, considers, get,
# Nearest to existence: alludes, divorces, blaxploitation, epidemiological, mattathias, scholarly, mut, petition,
# Nearest to scale: thermionic, fraktion, yerkes, rooted, fai, luminosity, preprocessing, subatomic,
# Nearest to event: sandwiches, mice, chastity, meteorologists, katz, principal, stress, inflating,
# Nearest to freedom: religious, danner, appeal, tendencies, fiscally, inquisitors, xps, colonna,
# Nearest to creation: detachments, taifa, spreads, thinking, luciano, disregards, translation, trinity,
# Nearest to shown: orthographic, about, achieve, flourish, read, kath, bona, utilized,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1555 0.0177 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2149 0.0167 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1858 0.0169 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1278 0.0170 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1930 0.0168 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1723 0.0168 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2021 0.0168 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1486 0.0167 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1255 0.0167 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.2085 0.0169 sec/batch
# Nearest to and: the, solving, canonical, rambo, steeply, uppermost, aquifer, pipelines,
# Nearest to he: his, tequila, had, confront, went, dundas, assault, entranced,
# Nearest to seven: two, four, five, six, nine, three, prasad, mallarm,
# Nearest to been: collider, taught, throughout, archeological, ruining, glyphs, broke, undetected,
# Nearest to for: sonic, rehabilitate, numeric, powerlessness, cour, herold, memorizing, belied,
# Nearest to if: nabla, opiates, integers, an, dirkjan, algorithm, deteriorates, exactly,
# Nearest to over: sagara, accede, attending, fed, tall, durante, dheas, quadrupole,
# Nearest to has: kettle, finland, cheapest, unbelievable, alkaline, bulletins, tram, nonconfirmative,
# Nearest to applications: original, cd, troma, recreating, repositories, dueling, emulator, daf,
# Nearest to something: looking, silence, dualism, standout, mlb, belles, wanting, transcend,
# Nearest to existence: alludes, rationalism, mut, scholarly, petition, divorces, mattathias, epidemiological,
# Nearest to scale: thermionic, fraktion, fai, luminosity, rooted, yerkes, accession, gms,
# Nearest to event: sandwiches, chastity, katz, meteorologists, mice, principal, stress, oscilloscopes,
# Nearest to freedom: danner, religious, tendencies, xps, appeal, distanced, inquisitors, scope,
# Nearest to creation: detachments, disregards, bitnet, spreads, ape, trinity, realists, taifa,
# Nearest to shown: orthographic, about, achieve, flourish, bona, read, kath, rigorous,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1798 0.0177 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1449 0.0168 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1601 0.0168 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1650 0.0167 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1478 0.0167 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1500 0.0171 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1530 0.0171 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1390 0.0171 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.2056 0.0168 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2113 0.0169 sec/batch
# Nearest to and: the, caleb, constituci, consultative, aquifer, steeply, peasantry, broglie,
# Nearest to he: his, had, confront, tequila, assault, odysseus, went, internationalist,
# Nearest to seven: two, four, five, six, nine, three, one, prasad,
# Nearest to been: collider, throughout, broke, ruining, taught, dumping, unattainable, resultant,
# Nearest to for: cour, herold, attorney, woodlawn, rehabilitate, belied, mandatory, elks,
# Nearest to if: opiates, nabla, integers, dirkjan, an, algorithm, get, deteriorates,
# Nearest to over: accede, sagara, tall, attending, quadrupole, durante, worsening, retconned,
# Nearest to has: kettle, finland, nonconfirmative, cheapest, robberies, unbelievable, malawian, bulletins,
# Nearest to applications: cd, original, recreating, repositories, dueling, emulator, troma, daf,
# Nearest to something: looking, dualism, standout, silence, mlb, belles, wanting, look,
# Nearest to existence: alludes, rationalism, mattathias, studia, divorces, petition, mut, blaxploitation,
# Nearest to scale: fraktion, thermionic, fai, luminosity, yerkes, seaboard, rooted, catalogued,
# Nearest to event: sandwiches, chastity, meteorologists, katz, principal, mice, oscilloscopes, chechen,
# Nearest to freedom: danner, xps, distanced, colonna, tendencies, youngstown, inquisitors, fiscally,
# Nearest to creation: detachments, bitnet, disregards, luciano, spreads, taifa, bunter, timepiece,
# Nearest to shown: orthographic, about, achieve, flourish, displeased, kath, read, bona,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2380 0.0178 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1501 0.0170 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0862 0.0170 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1512 0.0171 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0495 0.0174 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1397 0.0169 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1314 0.0169 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1439 0.0169 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1722 0.0023 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1036 0.0173 sec/batch
# Nearest to and: the, steeply, aquifer, pipelines, constituci, evolve, uppermost, most,
# Nearest to he: his, had, went, confront, assault, odysseus, tequila, nicolo,
# Nearest to seven: two, four, five, six, nine, three, one, zero,
# Nearest to been: collider, throughout, ruining, dumping, archeological, resultant, taught, broke,
# Nearest to for: belied, mandatory, herold, rehabilitate, ea, numeric, sonic, algorithm,
# Nearest to if: opiates, nabla, integers, algorithm, an, exactly, dirkjan, deteriorates,
# Nearest to over: sagara, accede, quadrupole, tall, miocene, est, worsening, retconned,
# Nearest to has: kettle, cheapest, bulletins, robberies, nonconfirmative, malawian, finland, with,
# Nearest to applications: original, cd, repositories, recreating, emulator, developers, windows, dueling,
# Nearest to something: looking, silence, standout, dualism, mlb, wanting, belles, globe,
# Nearest to existence: studia, mattathias, alludes, uncertainty, epidemiological, divorces, mut, blaxploitation,
# Nearest to scale: luminosity, fraktion, thermionic, fai, catalogued, preprocessing, yerkes, rooted,
# Nearest to event: sandwiches, katz, meteorologists, chastity, principal, oscilloscopes, chechen, professional,
# Nearest to freedom: danner, inquisitors, xps, distanced, phd, colonna, youngstown, fiscally,
# Nearest to creation: detachments, bitnet, disregards, spreads, luciano, evan, taifa, bunter,
# Nearest to shown: orthographic, about, achieve, flourish, kath, displeased, read, eunos,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0521 0.0177 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0566 0.0172 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.1081 0.0170 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0270 0.0170 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0583 0.0171 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0599 0.0173 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0760 0.0167 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1029 0.0167 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1135 0.0166 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0754 0.0168 sec/batch
# Nearest to and: the, steeply, aquifer, most, uppermost, pipelines, hydraulics, evolve,
# Nearest to he: his, had, confront, went, odysseus, underpants, searched, tequila,
# Nearest to seven: two, four, five, six, three, nine, one, mallarm,
# Nearest to been: collider, throughout, archeological, dumping, ruining, broke, frisians, siamese,
# Nearest to for: mandatory, rehabilitate, ea, numeric, megabyte, belied, algorithm, powerlessness,
# Nearest to if: opiates, nabla, integers, exactly, dirkjan, algorithm, an, deteriorates,
# Nearest to over: sagara, tall, quadrupole, miocene, minimi, accede, attending, fed,
# Nearest to has: kettle, cheapest, with, bulletins, alkaline, robberies, tram, nonconfirmative,
# Nearest to applications: original, recreating, cd, repositories, dueling, daf, emulator, ns,
# Nearest to something: looking, mlb, belles, dualism, wanting, silence, standout, globe,
# Nearest to existence: mattathias, studia, mut, alludes, uncertainty, divorces, blaxploitation, prester,
# Nearest to scale: luminosity, fraktion, thermionic, rooted, fai, yerkes, catalogued, preprocessing,
# Nearest to event: sandwiches, katz, chastity, meteorologists, principal, professional, mice, attention,
# Nearest to freedom: danner, distanced, inquisitors, colonna, forman, colonials, schlick, phd,
# Nearest to creation: bitnet, detachments, spreads, disregards, ventilated, faqs, bunter, luciano,
# Nearest to shown: orthographic, about, flourish, achieve, kath, displeased, read, bona,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0258 0.0176 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0163 0.0168 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0096 0.0172 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0562 0.0171 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0753 0.0167 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0555 0.0168 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0362 0.0167 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1244 0.0168 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0688 0.0169 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0381 0.0168 sec/batch
# Nearest to and: the, steeply, aquifer, solving, canonical, focused, evolve, consultative,
# Nearest to he: his, had, confront, went, searched, odysseus, tequila, directing,
# Nearest to seven: two, four, five, six, three, nine, one, prasad,
# Nearest to been: collider, throughout, archeological, dumping, taught, ruining, resultant, broke,
# Nearest to for: powerlessness, mandatory, numeric, algorithm, ea, belied, cour, herold,
# Nearest to if: nabla, an, opiates, integers, algorithm, exactly, will, deteriorates,
# Nearest to over: tall, sagara, fed, accede, quadrupole, minimi, miocene, attending,
# Nearest to has: kettle, nonconfirmative, bulletins, with, cheapest, robberies, alkaline, disagreeable,
# Nearest to applications: original, daf, cd, repositories, recreating, chem, dueling, ns,
# Nearest to something: looking, dualism, belles, silence, standout, mlb, wanting, subterfuge,
# Nearest to existence: mut, mattathias, studia, uncertainty, blaxploitation, alludes, divorces, rationalism,
# Nearest to scale: luminosity, fraktion, thermionic, rooted, catalogued, preprocessing, yerkes, fai,
# Nearest to event: sandwiches, chastity, katz, principal, meteorologists, mice, oscilloscopes, professional,
# Nearest to freedom: fiscally, danner, distanced, scope, youngstown, particulars, colonials, xps,
# Nearest to creation: detachments, bitnet, spreads, disregards, ventilated, bunter, luciano, faqs,
# Nearest to shown: orthographic, about, flourish, achieve, kath, talk, displeased, utilized,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0808 0.0178 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0935 0.0170 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0445 0.0170 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0944 0.0172 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0778 0.0169 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0457 0.0170 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0539 0.0171 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0417 0.0170 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0969 0.0168 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0530 0.0167 sec/batch
# Nearest to and: the, in, peasantry, aquifer, steeply, evolve, pipelines, canonical,
# Nearest to he: his, had, confront, went, dundas, odysseus, searched, entranced,
# Nearest to seven: two, four, five, six, three, nine, one, zero,
# Nearest to been: collider, throughout, broke, archeological, frisians, outflows, dumping, taught,
# Nearest to for: cour, mandatory, herold, powerlessness, belied, ea, its, numeric,
# Nearest to if: opiates, nabla, an, algorithm, integers, dirkjan, deteriorates, will,
# Nearest to over: accede, tall, sagara, six, worsening, minimi, quadrupole, zero,
# Nearest to has: kettle, nonconfirmative, with, cheapest, bulletins, robberies, finland, disagreeable,
# Nearest to applications: original, repositories, daf, cd, chem, recreating, aaai, ns,
# Nearest to something: looking, dualism, belles, mlb, silence, wanting, inwardly, standout,
# Nearest to existence: mattathias, mut, studia, scatter, uncertainty, blaxploitation, rationalism, papyri,
# Nearest to scale: fraktion, luminosity, rooted, thermionic, catalogued, yerkes, preprocessing, gms,
# Nearest to event: chastity, sandwiches, katz, meteorologists, principal, usually, mice, oscilloscopes,
# Nearest to freedom: danner, distanced, xps, fiscally, phd, scope, haploid, particulars,
# Nearest to creation: detachments, bitnet, disregards, taifa, trinity, spreads, bunter, faqs,
# Nearest to shown: orthographic, about, achieve, flourish, displeased, talk, kath, utilized,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0790 0.0176 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0187 0.0169 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0390 0.0166 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0864 0.0173 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0490 0.0168 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1300 0.0166 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1353 0.0169 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0671 0.0167 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0454 0.0168 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0315 0.0169 sec/batch
# Nearest to and: the, aquifer, in, most, peasantry, consultative, steeply, evolve,
# Nearest to he: his, had, confront, went, mamaea, searched, odysseus, chair,
# Nearest to seven: two, four, five, six, three, nine, zero, one,
# Nearest to been: collider, dumping, throughout, broke, frisians, outflows, archeological, recently,
# Nearest to for: mandatory, ea, letters, herold, powerlessness, belied, loser, alvin,
# Nearest to if: nabla, opiates, integers, will, an, dirkjan, algorithm, deteriorates,
# Nearest to over: accede, tall, sagara, quadrupole, six, miocene, zero, minimi,
# Nearest to has: kettle, with, robberies, nonconfirmative, cheapest, finland, competes, bulletins,
# Nearest to applications: repositories, daf, original, cd, dueling, aaai, recreating, chem,
# Nearest to something: looking, dualism, wanting, belles, silence, inwardly, mlb, windshield,
# Nearest to existence: mattathias, mut, studia, blaxploitation, uncertainty, scatter, papyri, divorces,
# Nearest to scale: fraktion, rooted, luminosity, catalogued, yerkes, villagers, preprocessing, fai,
# Nearest to event: katz, chastity, sandwiches, meteorologists, principal, drunkard, inflating, mice,
# Nearest to freedom: danner, fiscally, distanced, youngstown, schlick, xps, colonna, particulars,
# Nearest to creation: detachments, bitnet, bunter, disregards, faqs, luciano, taifa, evan,
# Nearest to shown: orthographic, about, displeased, achieve, talk, kath, flourish, read,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0159 0.0174 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9968 0.0167 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0424 0.0169 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0432 0.0173 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0772 0.0168 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0591 0.0146 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0268 0.0171 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9657 0.0171 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0139 0.0169 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9561 0.0173 sec/batch
# Nearest to and: the, in, peasantry, most, had, of, their, uppermost,
# Nearest to he: his, confront, had, went, chair, odysseus, mamaea, searched,
# Nearest to seven: two, four, five, six, nine, three, one, zero,
# Nearest to been: collider, dumping, throughout, archeological, frisians, later, broke, ruining,
# Nearest to for: herold, mandatory, ea, letters, belied, megabyte, algorithm, loser,
# Nearest to if: opiates, nabla, integers, an, dirkjan, algorithm, deteriorates, will,
# Nearest to over: tall, minimi, accede, miocene, quadrupole, fed, maariv, sagara,
# Nearest to has: kettle, with, cheapest, nonconfirmative, robberies, varies, competes, disagreeable,
# Nearest to applications: repositories, original, daf, dueling, recreating, ns, aaai, cd,
# Nearest to something: looking, dualism, belles, wanting, inwardly, silence, globe, standout,
# Nearest to existence: mut, mattathias, studia, uncertainty, scatter, papyri, blaxploitation, divorces,
# Nearest to scale: luminosity, fraktion, catalogued, rooted, preprocessing, yerkes, fai, observational,
# Nearest to event: katz, chastity, sandwiches, principal, meteorologists, usually, mice, inflating,
# Nearest to freedom: distanced, fiscally, danner, schlick, colonna, xps, particulars, phd,
# Nearest to creation: detachments, bitnet, disregards, created, spreads, faqs, bunter, luciano,
# Nearest to shown: orthographic, about, flourish, displeased, achieve, talk, kath, bona,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9705 0.0177 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9296 0.0173 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0048 0.0171 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0205 0.0172 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0200 0.0168 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9747 0.0171 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8885 0.0171 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9408 0.0171 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9572 0.0171 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9596 0.0170 sec/batch
# Nearest to and: the, in, most, of, aquifer, peasantry, their, steeply,
# Nearest to he: his, searched, had, odysseus, confront, went, chair, mamaea,
# Nearest to seven: two, four, five, six, three, nine, zero, one,
# Nearest to been: collider, dumping, throughout, archeological, broke, frisians, outflows, onerous,
# Nearest to for: mandatory, algorithm, ea, tnt, herold, loser, debit, belied,
# Nearest to if: nabla, opiates, integers, an, algorithm, deteriorates, will, dirkjan,
# Nearest to over: tall, miocene, fed, minimi, zero, accede, six, quadrupole,
# Nearest to has: with, kettle, competes, robberies, nonconfirmative, cheapest, varies, also,
# Nearest to applications: daf, repositories, ns, original, dueling, industrial, recreating, cd,
# Nearest to something: looking, dualism, mlb, belles, wanting, globe, silence, standout,
# Nearest to existence: mut, mattathias, scatter, uncertainty, papyri, studia, divorces, evidences,
# Nearest to scale: luminosity, rooted, fraktion, catalogued, preprocessing, thermionic, yerkes, mondegreen,
# Nearest to event: katz, chastity, meteorologists, sandwiches, principal, usually, mice, professional,
# Nearest to freedom: fiscally, distanced, danner, youngstown, colonials, chydenius, particulars, schlick,
# Nearest to creation: detachments, bitnet, disregards, luciano, faqs, created, ventilated, bunter,
# Nearest to shown: orthographic, about, displeased, flourish, talk, achieve, utilized, kath,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9918 0.0175 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0322 0.0168 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9640 0.0169 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9881 0.0169 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0359 0.0170 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9683 0.0169 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9915 0.0171 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0069 0.0172 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9751 0.0167 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9985 0.0165 sec/batch
# Nearest to and: the, in, of, peasantry, most, canonical, focused, consultative,
# Nearest to he: his, had, odysseus, searched, mamaea, chair, confront, graduated,
# Nearest to seven: two, four, five, nine, six, three, one, zero,
# Nearest to been: collider, throughout, dumping, broke, archeological, recently, outflows, later,
# Nearest to for: herold, mandatory, memorizing, belied, letters, loser, powerlessness, of,
# Nearest to if: opiates, an, dirkjan, will, nabla, deteriorates, algorithm, get,
# Nearest to over: minimi, tall, fed, zero, isomorphic, miocene, dinghy, two,
# Nearest to has: with, since, kettle, also, year, nonconfirmative, reason, robberies,
# Nearest to applications: daf, repositories, ns, original, aaai, recreating, dueling, industrial,
# Nearest to something: looking, dualism, belles, merriam, silence, globe, wanting, look,
# Nearest to existence: mut, mattathias, studia, rationalism, scatter, papyri, evidences, uncertainty,
# Nearest to scale: luminosity, rooted, fraktion, catalogued, mondegreen, yerkes, preprocessing, rameses,
# Nearest to event: katz, chastity, meteorologists, sandwiches, principal, usually, mice, number,
# Nearest to freedom: distanced, chydenius, danner, youngstown, xps, fiscally, schlick, haploid,
# Nearest to creation: created, bitnet, disregards, luciano, faqs, bunter, ventilated, nicholson,
# Nearest to shown: orthographic, about, displeased, achieve, flourish, talk, utilized, mortality,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0021 0.0177 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9966 0.0171 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9503 0.0182 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0083 0.0176 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0108 0.0171 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9929 0.0179 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9838 0.0176 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9436 0.0174 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9701 0.0166 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0439 0.0172 sec/batch
# Nearest to and: the, in, of, peasantry, most, a, canonical, their,
# Nearest to he: his, had, odysseus, chair, mamaea, graduated, searched, went,
# Nearest to seven: two, four, five, six, nine, three, zero, one,
# Nearest to been: dumping, onerous, later, recently, broke, collider, throughout, since,
# Nearest to for: herold, mandatory, of, its, netherlands, letters, the, in,
# Nearest to if: opiates, an, dirkjan, will, nabla, maybe, algorithm, trivial,
# Nearest to over: zero, two, tall, six, miocene, accede, est, five,
# Nearest to has: with, since, also, year, nonconfirmative, varies, kettle, article,
# Nearest to applications: daf, repositories, ns, dueling, original, aaai, smtp, windows,
# Nearest to something: looking, dualism, merriam, belles, get, look, wanting, connotations,
# Nearest to existence: mut, mattathias, scatter, studia, blaxploitation, uncertainty, evidences, papyri,
# Nearest to scale: luminosity, fraktion, rooted, catalogued, mondegreen, yerkes, preprocessing, rameses,
# Nearest to event: katz, chastity, meteorologists, principal, usually, sandwiches, number, mice,
# Nearest to freedom: distanced, chydenius, colonna, danner, youngstown, reprint, weblog, colonials,
# Nearest to creation: created, port, luciano, disregards, bitnet, bunter, detachments, hainaut,
# Nearest to shown: orthographic, displeased, about, achieve, talk, mortality, flourish, utilized,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9573 0.0179 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1022 0.0167 sec/batch
# ...
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8656 0.0181 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7395 0.0182 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.8234 0.0184 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7822 0.0185 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7996 0.0180 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8731 0.0185 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8793 0.0184 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8153 0.0185 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8377 0.0174 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9312 0.0177 sec/batch
# Nearest to and: the, of, in, with, a, for, most, four,
# Nearest to he: his, had, him, career, rennie, taught, went, deprogrammings,
# Nearest to seven: two, four, five, three, nine, one, six, zero,
# Nearest to been: later, recently, has, suggested, have, since, specifically, was,
# Nearest to for: in, the, and, of, on, is, as, to,
# Nearest to if: will, is, because, that, aretha, an, why, opiates,
# Nearest to over: zero, with, two, entire, non, s, six, est,
# Nearest to has: with, since, been, the, also, almost, which, but,
# Nearest to applications: daf, ns, industrial, frontend, esd, aaai, windows, curricula,
# Nearest to something: merriam, downstairs, looking, equalize, venn, windshield, connotations, aru,
# Nearest to existence: mut, mattathias, akira, scatter, proof, unusually, blaxploitation, prum,
# Nearest to scale: luminosity, rooted, fante, diatonic, computation, flanged, oratory, fraktion,
# Nearest to event: katz, meteorologists, chastity, events, lazio, cavett, skydiving, usually,
# Nearest to freedom: magnetometer, chydenius, prosperity, federalists, dualities, unimaginable, cleary, youngstown,
# Nearest to creation: created, odds, ape, closing, sacu, untapped, luciano, dermot,
# Nearest to shown: orthographic, displeased, bona, inverting, talk, grosser, euskal, toledo,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8356 0.0177 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8202 0.0188 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8399 0.0181 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8648 0.0179 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8538 0.0183 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8682 0.0180 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8706 0.0181 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8222 0.0180 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8781 0.0181 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8676 0.0173 sec/batch
# Nearest to and: the, of, in, with, to, also, most, a,
# Nearest to he: his, had, him, taught, career, was, rennie, went,
# Nearest to seven: two, five, four, three, nine, one, six, zero,
# Nearest to been: later, has, recently, suggested, since, have, was, specifically,
# Nearest to for: in, the, of, and, on, is, to, such,
# Nearest to if: is, that, aretha, an, will, because, option, why,
# Nearest to over: zero, two, with, five, entire, six, years, non,
# Nearest to has: with, since, been, the, also, which, but, of,
# Nearest to applications: daf, ns, industrial, frontend, esd, aaai, curricula, peyton,
# Nearest to something: merriam, downstairs, equalize, connotations, you, aru, looking, windshield,
# Nearest to existence: mut, akira, mattathias, proof, scatter, pictured, stoic, hormones,
# Nearest to scale: luminosity, fante, rooted, diatonic, flanged, computation, fluctuated, mondegreen,
# Nearest to event: katz, meteorologists, events, lazio, chastity, cavett, usually, describes,
# Nearest to freedom: magnetometer, chydenius, unimaginable, prosperity, dualities, bahamian, federalists, mercilessly,
# Nearest to creation: created, odds, closing, sacu, ape, luciano, port, untapped,
# Nearest to shown: orthographic, displeased, bona, toledo, talk, grosser, inverting, revived,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8673 0.0180 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8483 0.0176 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8518 0.0187 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8242 0.0177 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8772 0.0176 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8409 0.0181 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9504 0.0181 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9083 0.0181 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9094 0.0175 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8180 0.0186 sec/batch
# Nearest to and: the, in, of, with, to, most, four, also,
# Nearest to he: his, had, career, him, was, rennie, taught, went,
# Nearest to seven: two, four, five, three, one, six, nine, zero,
# Nearest to been: has, later, recently, have, suggested, was, specifically, since,
# Nearest to for: the, in, of, on, and, is, as, to,
# Nearest to if: is, that, aretha, will, be, it, because, why,
# Nearest to over: zero, two, five, with, s, six, est, years,
# Nearest to has: with, since, the, been, also, but, which, of,
# Nearest to applications: daf, ns, frontend, aaai, industrial, esd, curricula, windows,
# Nearest to something: merriam, you, equalize, downstairs, aru, venn, looking, temporally,
# Nearest to existence: mut, akira, proof, mattathias, scatter, cementing, stoic, pictured,
# Nearest to scale: luminosity, rooted, diatonic, fante, computation, flanged, oratory, fluctuated,
# Nearest to event: katz, meteorologists, lazio, chastity, cavett, describes, events, lilienthal,
# Nearest to freedom: magnetometer, chydenius, unimaginable, right, mercilessly, colonials, federalists, prosperity,
# Nearest to creation: created, sacu, closing, odds, untapped, luciano, bunter, dermot,
# Nearest to shown: displeased, orthographic, bona, talk, toledo, grosser, inverting, revived,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7848 0.0184 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8715 0.0180 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7979 0.0171 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8708 0.0185 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8481 0.0181 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8387 0.0191 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9350 0.0066 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8094 0.0183 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8553 0.0181 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8262 0.0179 sec/batch
# Nearest to and: the, of, in, with, to, four, a, most,
# Nearest to he: his, had, him, was, career, taught, rennie, himself,
# Nearest to seven: two, four, five, three, one, six, nine, zero,
# Nearest to been: have, later, has, recently, suggested, was, specifically, archeological,
# Nearest to for: of, in, and, the, on, is, as, its,
# Nearest to if: is, that, aretha, because, an, be, why, will,
# Nearest to over: zero, two, with, entire, years, est, five, s,
# Nearest to has: with, since, been, also, the, almost, which, most,
# Nearest to applications: daf, ns, frontend, aaai, industrial, windows, esd, repositories,
# Nearest to something: downstairs, merriam, equalize, you, aru, connotations, venn, tell,
# Nearest to existence: mut, akira, proof, mattathias, unusually, stoic, scatter, hormones,
# Nearest to scale: diatonic, luminosity, scales, computation, fante, flanged, lieder, rooted,
# Nearest to event: katz, meteorologists, lazio, cavett, lilienthal, chastity, skydiving, events,
# Nearest to freedom: chydenius, magnetometer, federalists, dualities, mercilessly, liberty, prosperity, right,
# Nearest to creation: created, sacu, closing, luciano, untapped, odds, prut, bunter,
# Nearest to shown: displeased, orthographic, bona, grosser, toledo, talk, inverting, euskal,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8707 0.0190 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8005 0.0172 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8272 0.0178 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7798 0.0172 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8313 0.0177 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8465 0.0181 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8761 0.0176 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7665 0.0181 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7815 0.0186 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8493 0.0182 sec/batch
# Nearest to and: the, in, of, with, to, a, for, is,
# Nearest to he: his, him, career, had, taught, went, rennie, himself,
# Nearest to seven: two, four, five, three, one, six, nine, zero,
# Nearest to been: has, have, recently, later, suggested, were, specifically, since,
# Nearest to for: the, and, of, in, is, to, as, on,
# Nearest to if: be, that, is, will, cannot, to, because, it,
# Nearest to over: zero, two, with, five, years, six, entire, s,
# Nearest to has: with, been, the, since, also, a, but, of,
# Nearest to applications: daf, ns, frontend, industrial, aaai, esd, akiva, curricula,
# Nearest to something: downstairs, merriam, you, aru, looking, equalize, connotations, tell,
# Nearest to existence: mut, akira, mattathias, proof, hormones, unusually, cementing, scatter,
# Nearest to scale: luminosity, diatonic, fante, computation, scales, rooted, fluctuated, flanged,
# Nearest to event: katz, meteorologists, lazio, chastity, cavett, events, describes, skydiving,
# Nearest to freedom: magnetometer, chydenius, mercilessly, federalists, prosperity, reprint, colonials, dualities,
# Nearest to creation: created, sacu, odds, untapped, closing, luciano, uvular, contends,
# Nearest to shown: displeased, orthographic, bona, toledo, formal, talk, grosser, revived,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7536 0.0181 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8097 0.0178 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8547 0.0181 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8414 0.0174 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8297 0.0173 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8905 0.0193 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8344 0.0180 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8201 0.0182 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8570 0.0184 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8478 0.0183 sec/batch
# Nearest to and: the, in, of, with, to, for, four, most,
# Nearest to he: his, had, career, him, rennie, taught, went, was,
# Nearest to seven: two, five, four, three, one, nine, six, zero,
# Nearest to been: has, recently, later, have, suggested, was, were, first,
# Nearest to for: the, and, in, of, is, to, on, as,
# Nearest to if: is, aretha, will, because, that, why, be, an,
# Nearest to over: zero, two, five, with, s, entire, years, six,
# Nearest to has: with, the, been, since, a, of, also, in,
# Nearest to applications: daf, ns, industrial, aaai, frontend, akiva, esd, fortunate,
# Nearest to something: merriam, downstairs, equalize, connotations, aru, you, venn, downwards,
# Nearest to existence: mut, akira, stoic, mattathias, proof, kang, hormones, cementing,
# Nearest to scale: luminosity, diatonic, fante, computation, janis, fluctuated, mondegreen, flanged,
# Nearest to event: katz, meteorologists, cavett, lazio, describes, chastity, usually, events,
# Nearest to freedom: magnetometer, free, chydenius, dualities, reprint, mercilessly, cleary, federalists,
# Nearest to creation: created, odds, sacu, untapped, contends, uvular, closing, beginnings,
# Nearest to shown: displeased, orthographic, bona, talk, toledo, formal, revived, inverting,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8761 0.0181 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8247 0.0167 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8112 0.0174 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8606 0.0179 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8222 0.0177 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8460 0.0182 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8413 0.0177 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8439 0.0176 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8181 0.0188 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8164 0.0173 sec/batch
# Nearest to and: the, in, of, with, for, to, four, a,
# Nearest to he: his, him, had, career, rennie, went, taught, was,
# Nearest to seven: two, five, four, three, one, six, nine, zero,
# Nearest to been: has, have, later, recently, was, suggested, that, were,
# Nearest to for: the, and, in, of, is, to, on, as,
# Nearest to if: is, that, an, will, to, because, aretha, option,
# Nearest to over: zero, two, five, six, three, with, years, s,
# Nearest to has: with, the, been, since, also, of, a, in,
# Nearest to applications: daf, ns, industrial, aaai, frontend, akiva, peyton, fortunate,
# Nearest to something: merriam, you, equalize, connotations, aru, downstairs, downwards, tell,
# Nearest to existence: mut, akira, mattathias, hormones, proof, scatter, cementing, stoic,
# Nearest to scale: luminosity, diatonic, fante, computation, janis, fluctuated, scales, our,
# Nearest to event: katz, meteorologists, lazio, events, describes, usually, cavett, chastity,
# Nearest to freedom: magnetometer, reprint, chydenius, free, dualities, mercilessly, cleary, right,
# Nearest to creation: created, sacu, odds, untapped, spoiler, beginnings, port, uvular,
# Nearest to shown: displeased, orthographic, bona, talk, toledo, formal, inverting, revived,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8571 0.0188 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8263 0.0179 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8807 0.0170 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9421 0.0184 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8836 0.0179 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8445 0.0179 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7731 0.0176 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8590 0.0172 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7117 0.0190 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8449 0.0175 sec/batch
# Nearest to and: the, in, of, with, to, for, also, most,
# Nearest to he: his, had, him, career, rennie, taught, doctorate, went,
# Nearest to seven: five, two, four, three, one, nine, six, zero,
# Nearest to been: has, have, recently, later, suggested, recent, was, were,
# Nearest to for: the, and, of, in, on, as, is, to,
# Nearest to if: that, will, aretha, is, it, be, because, say,
# Nearest to over: zero, two, years, five, with, six, s, est,
# Nearest to has: with, been, the, since, in, also, a, of,
# Nearest to applications: daf, ns, frontend, aaai, esd, fortunate, windows, akiva,
# Nearest to something: merriam, aru, equalize, downstairs, you, connotations, downwards, nothing,
# Nearest to existence: mut, akira, mattathias, hormones, kang, proof, nonexistence, unusually,
# Nearest to scale: diatonic, luminosity, fante, computation, janis, our, scales, fluctuated,
# Nearest to event: katz, meteorologists, lazio, cavett, events, lilienthal, describes, chastity,
# Nearest to freedom: magnetometer, chydenius, prosperity, free, federalists, liberty, mercilessly, colonials,
# Nearest to creation: created, sacu, untapped, spoiler, odds, beginnings, nursultan, uvular,
# Nearest to shown: displeased, orthographic, bona, talk, formal, inverting, toledo, revived,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8361 0.0172 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8174 0.0178 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
